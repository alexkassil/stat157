# %%
import pandas as pd
import numpy as np

# %%
data_dir = "./data/demo_r_pjangroup.tsv"

# %%
data = pd.DataFrame.from_csv(data_dir, sep='\t')
data
# Out:
#                           2018      2017      2016      2015       2014   \
# unit,sex,age,geo\time
# NR,F,TOTAL,AL          1431715   1423050   1417141   1424597    1430827
# NR,F,TOTAL,AL0         1431715   1423050   1417141   1424597    1430827
# NR,F,TOTAL,AL01         405598    405835    416845         :          :
# NR,F,TOTAL,AL02         585530    574010    552949         :          :
# NR,F,TOTAL,AL03         440587    443205    454906         :          :
# NR,F,TOTAL,ALXX              0         :         :         :          :
# NR,F,TOTAL,AT          4483749   4460424   4427918   4384529    4352447
# NR,F,TOTAL,AT1         1964998   1952123   1934748   1909925    1891217
# NR,F,TOTAL,AT11         149016    148416    148052    147246     146980
# NR,F,TOTAL,AT12         847971    845249    839555    832975     828087
# NR,F,TOTAL,AT13         968011    958458    947141    929704     916150
# NR,F,TOTAL,AT2          915571    914535    911819    907636     905201
# ...

# %%
indices = []
for val in data.index:
    split = val.split(',')
    indices.append(len(split[-1]) == 2 and split[-2] == "TOTAL" and split[-3] == 'T')

# %%
data = data[indices]

# %%
two_letter_to_country_name = \
{
    "AL": "Albania",
    "AT": "Austria",
    "BE": "Belgium",
    "BG": "Bulgaria",
    "CH": "Switzerland",
    "CY": "Cyprus",
    "CZ": "Czech Republic",
    "DE": "Germany",
    "DK": "Denmark",
    "EE": "Estonia",
    "EL": "Greece",
    "ES": "Spain",
    "FI": "Finland",
    "FR": "France",
    "HR": "Croatia",
    "HU": "Hungary",
    "IE": "Ireland",
    "IS": "Iceland",
    "IT": "Italy",
    "LI": "Liechtenstein",
    "LT": "Lithuania",
    "LU": "Luxembourg",
    "LV": "Latvia",
    "ME": "Montenegro",
    "MK": "North Macedonia",
    "MT": "Malta",
    "NL": "Netherlands",
    "NO": "Norway",
    "PL": "Poland",
    "PT": "Portugal",
    "RO": "Romania",
    "RS": "Serbia",
    "SE": "Sweden",
    "SI": "Slovenia",
    "SK": "Slovakia",
    "TR": "Turkey",
    "UK": "United Kingdom"
    
}

# %%
data.index = pd.Index(list(map(lambda x: two_letter_to_country_name[x.split(',')[-1]], data.index)))
data
# Out:
#                      2018       2017        2016        2015        2014   \
# Albania           2870324    2876591     2875592     2885796     2892394
# Austria           8822267    8772865     8700471     8584926     8507786
# Belgium          11398589   11351727    11311117    11237274   11180840 b
# Bulgaria          7050034    7101859     7153784     7202198     7245677
# Switzerland       8484130    8419550     8327126     8237666     8139631
# Cyprus             864236     854802      848319      847008      858000
# Czech Republic   10610055   10578820    10553843    10538275    10512419
# Germany          82792351   82521653    82175684    81197537    80767463
# Denmark           5781190    5748769     5707251     5659715     5627235
# Estonia           1319133    1315635     1315944    1314870 b    1315819
# Greece           10741165   10768193    10783748    10858018    10926807
# Spain            46658447   46528024    46440099    46449565    46512199
# ...
